# %%
# Load the text from the file
if  prompt_dropdown.value == 'No Context 1 - No Min MPa':
    with open('../prompts/optimal_target_value_no_context_1.txt', 'r') as f:
        lines = f.read().splitlines()
elif prompt_dropdown.value == 'No Context 2 - No Min MPa':
    with open('../prompts/optimal_target_value_no_context_2.txt', 'r') as f:
        lines = f.read().splitlines()
elif prompt_dropdown.value == 'No Context 3 - No Min MPa':
    with open('../prompts/optimal_target_value_no_context_3.txt', 'r') as f:
        ines = f.read().splitlines()
elif prompt_dropdown.value == 'Specific Context 1 - No Min MPa':
    with open('../prompts/optimal_value_specific_context_1.txt', 'r') as f:
        lines = f.read().splitlines()
elif prompt_dropdown.value == 'Specific Context 2 - No Min MPa':
    with open('../prompts/optimal_value_specific_context_2.txt', 'r') as f:
        lines = f.read().splitlines()
elif prompt_dropdown.value == 'Specific Context 3 - No Min MPa':
    with open('../prompts/optimal_value_specific_context_3.txt', 'r') as f:
        lines = f.read().splitlines()
elif  prompt_dropdown.value == 'No Context 1 - Specified Min MPa':
    with open('../prompts/min_target_value_no_context_1.txt', 'r') as f:
        lines = f.read().splitlines()
elif prompt_dropdown.value == 'No Context 2 - Specified Min MPa':
    with open('../prompts/min_target_value_no_context_2.txt', 'r') as f:
        lines = f.read().splitlines()
elif prompt_dropdown.value == 'No Context 3 - Specified Min MPa':
    with open('../prompts/min_target_value_no_context_3.txt', 'r') as f:
        ines = f.read().splitlines()
elif prompt_dropdown.value == 'Specific Context 1 - Specified Min MPa':
    with open('../prompts/min_target_value_specific_context_1.txt', 'r') as f:
        lines = f.read().splitlines()
elif prompt_dropdown.value == 'Specific Context 2 - Specified Min MPa':
    with open('../prompts/min_target_value_specific_context_2.txt', 'r') as f:
        lines = f.read().splitlines()
elif prompt_dropdown.value == 'Specific Context 3 - Specified Min MPa':
    with open('../prompts/min_target_value_specific_context_3.txt', 'r') as f:
        lines = f.read().splitlines()

    
    
DA_role_text = lines[0]
context_text = lines[1]
iterate_text = lines[2]
VM_role_text = lines[3]
    
if minimal_target_value_dropdown.value == 'yes':
    DA_role_text = DA_role_text.replace('custom_minimal_target_value', str(minimal_target_value_input.value))

# Create the widgets with the loaded text
layout = widgets.Layout(width='auto', height='200px')  # adjust the height and width as needed
#instructions_prompt = widgets.Textarea(value=instructions_text, description='Instructions:', layout=layout)
DA_role_prompt = widgets.Textarea(value=DA_role_text, description='DA Instuctions:', layout=layout)
VM_role_prompt = widgets.Textarea(value=VM_role_text, description='VM Instuctions:', layout=layout)
context_prompt = widgets.Textarea(value=context_text, description='Design Knowledge (Context):', layout=layout)
iterate_prompt = widgets.Textarea(value=iterate_text, description='User:', layout=layout)

prompt_container = widgets.VBox([DA_role_prompt, VM_role_prompt, context_prompt, iterate_prompt])
title = widgets.HTML("<h1>Great! Below, you may edit the prompt that will be used for the experiments: </h1>")
display(title, prompt_container)
